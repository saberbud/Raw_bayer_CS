# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import h5py
import os
np.random.seed(73)
import skimage
from PIL import Image
from skimage.measure import compare_ssim,compare_psnr

# %%
#fname='/Users/xy-work/testfolder/test_DM_big_frame/Frame_19_7/DM_orig.h5'
fname='./DM_orig.h5'
f_i=h5py.File(fname,'r')
image_orig=f_i['data'][:]
print("image_orig shape: " + str(image_orig.shape))
# Out:
# image_orig shape: (2048, 3840, 3)

# %%
print("image_orig shape= " + str(image_orig.shape) + " , max= " + str(np.max(image_orig)) 
      + " , min= " + str(np.min(image_orig)) + " , mean= " + str(np.mean(image_orig)))
# Out:
# image_orig shape= (2048, 3840, 3) , max= 0.8941176470588236 , min= 0.0 , mean= 0.4475208403809651

# %%
plt.figure(figsize=(14, 18))
plt.imshow(image_orig)

# %%
def trans_JPEG(data, QP):
    tmp=data*255.
    tmpu8=tmp.astype(np.uint8)
    im = Image.fromarray(tmpu8)
    im.save("./tmp.jpeg",quality=QP)
    size=os.path.getsize("./tmp.jpeg")
    tim=Image.open("./tmp.jpeg")
    tima=np.array(tim)
    rdf32=tima.astype(np.float32)/255.
    return rdf32, size

# %%
xjp,size=trans_JPEG(image_orig,2)

# %%
print("xjp shape= " + str(xjp.shape) + " , max= " + str(np.max(xjp)) 
      + " , min= " + str(np.min(xjp)) + " , mean= " + str(np.mean(xjp)))
print("size= " + str(size))
print("ratio= " + str(2048*3840*3/size))
# Out:
# xjp shape= (2048, 3840, 3) , max= 0.9254902 , min= 0.0 , mean= 0.4556566
# size= 128659
# ratio= 183.37590063656643

# %%
plt.figure(figsize=(14, 18))
plt.imshow(xjp)

# %%
output=(xjp*255).astype('uint8')
label=(image_orig*255).astype('uint8')
psnr =compare_psnr(output, label)
ssim =compare_ssim(output, label, multichannel=True)

print("psnr= " + str(psnr))
print("ssim= " + str(ssim))
# Out:
# psnr= 25.685557470905227
# ssim= 0.8168379716383326

# %%
xjp,size=trans_JPEG(image_orig,80)

# %%
print("xjp shape= " + str(xjp.shape) + " , max= " + str(np.max(xjp)) 
      + " , min= " + str(np.min(xjp)) + " , mean= " + str(np.mean(xjp)))
print("size= " + str(size))
print("ratio= " + str(2048*3840*3/size))
# Out:
# xjp shape= (2048, 3840, 3) , max= 0.92941177 , min= 0.007843138 , mean= 0.44751638
# size= 508440
# ratio= 46.402643379749826

# %%
plt.figure(figsize=(14, 18))
plt.imshow(xjp)

# %%
output=(xjp*255).astype('uint8')
label=(image_orig*255).astype('uint8')
psnr =compare_psnr(output, label)
ssim =compare_ssim(output, label, multichannel=True)

print("psnr= " + str(psnr))
print("ssim= " + str(ssim))
# Out:
# psnr= 41.325162604598454
# ssim= 0.9527268908750811

# %%
xjp,size=trans_JPEG(image_orig,60)
print("xjp shape= " + str(xjp.shape) + " , max= " + str(np.max(xjp)) 
      + " , min= " + str(np.min(xjp)) + " , mean= " + str(np.mean(xjp)))
print("size= " + str(size))
print("ratio= " + str(2048*3840*3/size))
# Out:
# xjp shape= (2048, 3840, 3) , max= 0.90588236 , min= 0.0 , mean= 0.44806552
# size= 297665
# ratio= 79.2601078393496

# %%
plt.figure(figsize=(14, 18))
plt.imshow(xjp)

# %%
output=(xjp*255).astype('uint8')
label=(image_orig*255).astype('uint8')
psnr =compare_psnr(output, label)
ssim =compare_ssim(output, label, multichannel=True)

print("psnr= " + str(psnr))
print("ssim= " + str(ssim))
# Out:
# psnr= 39.96216387993809
# ssim= 0.9438773644568799

# %%
xjp,size=trans_JPEG(image_orig,44)
print("xjp shape= " + str(xjp.shape) + " , max= " + str(np.max(xjp)) 
      + " , min= " + str(np.min(xjp)) + " , mean= " + str(np.mean(xjp)))
print("size= " + str(size))
print("ratio= " + str(2048*3840*3/size))
# Out:
# xjp shape= (2048, 3840, 3) , max= 0.9137255 , min= 0.0 , mean= 0.44804958
# size= 250892
# ratio= 94.0363184158921

# %%
plt.figure(figsize=(14, 18))
plt.imshow(xjp)

# %%
output=(xjp*255).astype('uint8')
label=(image_orig*255).astype('uint8')
psnr =compare_psnr(output, label)
ssim =compare_ssim(output, label, multichannel=True)

print("psnr= " + str(psnr))
print("ssim= " + str(ssim))
# Out:
# psnr= 39.101375001235006
# ssim= 0.9380060901458463
