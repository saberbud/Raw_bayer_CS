# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import h5py
import os
np.random.seed(73)
import skimage
from PIL import Image
from skimage.measure import compare_ssim,compare_psnr

# %%
#fname='/Users/xy-work/testfolder/test_DM_big_frame/Frame_19_7/DM_orig.h5'
fname='./DM_orig.h5'
f_i=h5py.File(fname,'r')
image_orig=f_i['data'][:]
print("image_orig shape: " + str(image_orig.shape))
# Out:
# image_orig shape: (2048, 3840, 3)

# %%
print("image_orig shape= " + str(image_orig.shape) + " , max= " + str(np.max(image_orig)) 
      + " , min= " + str(np.min(image_orig)) + " , mean= " + str(np.mean(image_orig)))
# Out:
# image_orig shape= (2048, 3840, 3) , max= 0.8980392156862745 , min= 0.0 , mean= 0.35638052414705

# %%
plt.figure(figsize=(14, 18))
plt.imshow(image_orig)

# %%
def trans_JPEG(data, QP):
    tmp=data*255.
    tmpu8=tmp.astype(np.uint8)
    im = Image.fromarray(tmpu8)
    im.save("./tmp.jpeg",quality=QP)
    size=os.path.getsize("./tmp.jpeg")
    tim=Image.open("./tmp.jpeg")
    tima=np.array(tim)
    rdf32=tima.astype(np.float32)/255.
    return rdf32, size

# %%
xjp,size=trans_JPEG(image_orig,2)

# %%
print("xjp shape= " + str(xjp.shape) + " , max= " + str(np.max(xjp)) 
      + " , min= " + str(np.min(xjp)) + " , mean= " + str(np.mean(xjp)))
print("size= " + str(size))
print("ratio= " + str(2048*3840*3/size))
# Out:
# xjp shape= (2048, 3840, 3) , max= 1.0 , min= 0.0 , mean= 0.35474423
# size= 129077
# ratio= 182.78206032058384

# %%
plt.figure(figsize=(14, 18))
plt.imshow(xjp)

# %%
output=(xjp*255).astype('uint8')
label=(image_orig*255).astype('uint8')
psnr =compare_psnr(output, label)
ssim =compare_ssim(output, label, multichannel=True)

print("psnr= " + str(psnr))
print("ssim= " + str(ssim))
# Out:
# psnr= 23.59499496456872
# ssim= 0.8151836376440652

# %%
xjp,size=trans_JPEG(image_orig,83)

# %%
print("xjp shape= " + str(xjp.shape) + " , max= " + str(np.max(xjp)) 
      + " , min= " + str(np.min(xjp)) + " , mean= " + str(np.mean(xjp)))
print("size= " + str(size))
print("ratio= " + str(2048*3840*3/size))
# Out:
# xjp shape= (2048, 3840, 3) , max= 0.9137255 , min= 0.0 , mean= 0.35665902
# size= 489003
# ratio= 48.24706596892044

# %%
plt.figure(figsize=(14, 18))
plt.imshow(xjp)

# %%
output=(xjp*255).astype('uint8')
label=(image_orig*255).astype('uint8')
psnr =compare_psnr(output, label)
ssim =compare_ssim(output, label, multichannel=True)

print("psnr= " + str(psnr))
print("ssim= " + str(ssim))
# Out:
# psnr= 43.38510599684997
# ssim= 0.9669479249915472

# %%
xjp,size=trans_JPEG(image_orig,69)
print("xjp shape= " + str(xjp.shape) + " , max= " + str(np.max(xjp)) 
      + " , min= " + str(np.min(xjp)) + " , mean= " + str(np.mean(xjp)))
print("size= " + str(size))
print("ratio= " + str(2048*3840*3/size))
# Out:
# xjp shape= (2048, 3840, 3) , max= 0.91764706 , min= 0.0 , mean= 0.3568278
# size= 290506
# ratio= 81.21333122207459

# %%
plt.figure(figsize=(14, 18))
plt.imshow(xjp)

# %%
output=(xjp*255).astype('uint8')
label=(image_orig*255).astype('uint8')
psnr =compare_psnr(output, label)
ssim =compare_ssim(output, label, multichannel=True)

print("psnr= " + str(psnr))
print("ssim= " + str(ssim))
# Out:
# psnr= 42.47082163503418
# ssim= 0.9624765620947401

# %%
xjp,size=trans_JPEG(image_orig,58)
print("xjp shape= " + str(xjp.shape) + " , max= " + str(np.max(xjp)) 
      + " , min= " + str(np.min(xjp)) + " , mean= " + str(np.mean(xjp)))
print("size= " + str(size))
print("ratio= " + str(2048*3840*3/size))
# Out:
# xjp shape= (2048, 3840, 3) , max= 0.9137255 , min= 0.0 , mean= 0.3571144
# size= 246963
# ratio= 95.53236719670558

# %%
plt.figure(figsize=(14, 18))
plt.imshow(xjp)

# %%
output=(xjp*255).astype('uint8')
label=(image_orig*255).astype('uint8')
psnr =compare_psnr(output, label)
ssim =compare_ssim(output, label, multichannel=True)

print("psnr= " + str(psnr))
print("ssim= " + str(ssim))
# Out:
# psnr= 41.749185306839856
# ssim= 0.9596893933209195
